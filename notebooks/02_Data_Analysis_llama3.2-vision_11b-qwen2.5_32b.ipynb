# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
from pathlib import Path

# check if workding_dir is in local variables
if "workding_dir" not in locals():
    workding_dir = str(Path.cwd().parent)

os.chdir(workding_dir)
sys.path.append(workding_dir)
print("workding dir:", workding_dir)
# Out:
# workding dir: /Users/inflaton/code/engd/papers/sme-invoicing-assistant

# %%
from dotenv import find_dotenv, load_dotenv

found_dotenv = find_dotenv(".env")

if len(found_dotenv) == 0:
    found_dotenv = find_dotenv(".env.example")
print(f"loading env vars from: {found_dotenv}")
load_dotenv(found_dotenv, override=True)
# Out:
# loading env vars from: /Users/inflaton/code/engd/papers/sme-invoicing-assistant/.env
# True

# %%
import pandas as pd
import sqlite3

# Connect to SQLite database
conn = sqlite3.connect("results/llama3.2-vision_11b-qwen2.5_32b/emails.db")
# conn = sqlite3.connect("src/data/db/llama3.2-vision_11b-qwen2.5_32b/emails.db")

# Write your SQL query
query = "SELECT * FROM emails"

# Read the query results into a pandas DataFrame
df = pd.read_sql(query, conn)

df.head(5)
# Out:
#                            email_id                sender_email  \
# 0  93185A89130149C0A842968E4AFDCAA2     RobinLevine@example.com
# 1  614972488B7B411BAEA4814CF066CDAA     StevenNixon@example.com
# 2  C484ABEB38F44D29960B1CEF58510627     MadisonFord@example.com
# 3  706B3403E8024178948B3BFBF9E64A25    KathrynJones@example.com
# 4  86838440CA6C472AACFA3FCE1382609C  ChristineOwens@example.com
#
#                 recipient_email                                     subject  \
# 0  tanya.official.456@gmail.com  Payment Confirmation for Invoice ID: 43925
# 1  tanya.official.456@gmail.com  Payment Confirmation for Invoice ID: 51782
# 2  tanya.official.456@gmail.com  Payment Confirmation for Invoice ID: 42968
# 3  tanya.official.456@gmail.com  Payment Confirmation for Invoice ID: 92948
# 4  tanya.official.456@gmail.com  Payment Confirmation for Invoice ID: 20304
#
#                                           email_body         attachments  \
# 0  Hi Tanya ! Please find attached payment screen...  transaction_1.jpeg
# 1  Hi Tanya ! Please find attached payment screen...  transaction_2.jpeg
# 2  Hi Tanya ! Please find attached payment screen...  transaction_3.jpeg
# 3  Hi Tanya ! Please find attached payment screen...  transaction_4.jpeg
# 4  Hi Tanya ! Please find attached payment screen...  transaction_5.jpeg
#
#   process_status             response                  start_time  \
# 0        SUCCESS  {"content": "DONE"}  2025-01-19T12:38:44.897633
# 1        SUCCESS  {"content": "DONE"}  2025-01-19T12:39:22.186091
# 2        SUCCESS  {"content": "DONE"}  2025-01-19T12:39:33.458549
# 3        SUCCESS  {"content": "DONE"}  2025-01-19T12:39:44.225788
# 4        SUCCESS  {"content": "DONE"}  2025-01-19T12:39:57.159558
#
#                      end_time total_time successful_requests total_tokens  \
# 0  2025-01-19T12:39:22.174910     0.2773                   8         2828
# 1  2025-01-19T12:39:33.450020     0.2639                  28        10314
# 2  2025-01-19T12:39:44.217607     0.7591                  60        22347
# 3  2025-01-19T12:39:57.151574     0.9258                 104        39028
# 4  2025-01-19T12:40:08.401280     0.2417                 160        60377
#
#   prompt_tokens completion_tokens total_cost
# 0          2302               526        0.0
# 1          8452              1862        0.0
# 2         18459              3888        0.0
# 3         32374              6654        0.0
# 4         50201             10176        0.0

# %%
import json

json_file = "results/llama3.2-vision_11b-qwen2.5_32b/full_logs.json"

if "full_logs" in df.columns:
    last_completed = df[df["full_logs"] != ""].iloc[-1]
    full_logs = json.loads(last_completed["full_logs"])
    json.dump(full_logs, open(json_file, "w"), indent=4)
    conn.execute("ALTER TABLE emails DROP COLUMN full_logs")
    conn.execute("VACUUM")
    conn.commit()
    print("full_logs saved to", json_file)
else:
    full_logs = json.load(open(json_file))
    print("full_logs loaded from", json_file)

# Close the connection
conn.close()
# Out:
# full_logs loaded from results/llama3.2-vision_11b-qwen2.5_32b/full_logs.json

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   email_id             2000 non-null   object
#  1   sender_email         2000 non-null   object
#  2   recipient_email      2000 non-null   object
#  3   subject              2000 non-null   object
#  4   email_body           2000 non-null   object
#  5   attachments          2000 non-null   object
#  6   process_status       2000 non-null   object
#  7   response             2000 non-null   object
#  8   start_time           2000 non-null   object
#  9   end_time             2000 non-null   object
#  10  total_time           2000 non-null   object
#  11  successful_requests  2000 non-null   object
#  12  total_tokens         2000 non-null   object
#  13  prompt_tokens        2000 non-null   object
#  14  completion_tokens    2000 non-null   object
#  15  total_cost           2000 non-null   object
# dtypes: object(16)
# memory usage: 250.1+ KB

# %%
df.describe()
# Out:
#                                 email_id              sender_email  \
# count                               2000                      2000
# unique                              2000                      1988
# top     93185A89130149C0A842968E4AFDCAA2  MichaelJones@example.com
# freq                                   1                         3
#
#                      recipient_email                                  subject  \
# count                           2000                                     2000
# unique                             1                                     1947
# top     tanya.official.456@gmail.com  Payment Confirmation for Invoice I13212
# freq                            2000                                        3
#
#                                                email_body attachments  \
# count                                                2000        2000
# unique                                               2000        1001
# top     Hi Tanya ! Please find attached payment screen...
# freq                                                    1        1000
#
#        process_status             response                  start_time  \
# count            2000                 2000                        2000
# unique              2                   56                        2000
# top           SUCCESS  {"content": "DONE"}  2025-01-19T12:38:44.897633
# freq             1945                 1945                           1
#
#                           end_time total_time successful_requests  \
# count                         2000       2000                2000
# unique                        2000       1815                2000
# top     2025-01-19T12:39:22.174910     0.8079                   8
# freq                             1          3                   1
#
#        total_tokens prompt_tokens completion_tokens total_cost
# count          2000          2000              2000       2000
# unique         2000          2000              2000          1
# top            2828          2302               526        0.0
# freq              1             1                 1       2000

# %%
# plot the distribution of categories
import matplotlib.pyplot as plt


def plot_value_distribution(df2, col="category", top_n=10):
    df2[col].value_counts()[:top_n].plot(kind="bar")
    plt.title(f"Distribution of {col}")

    # add the count on top of the bars
    for i in range(len(df2[col].value_counts()[:top_n])):
        count = df2[col].value_counts().values[i]
        plt.text(i, count, count, ha="center")

    plt.show()

# %%
plot_value_distribution(df, "process_status")

# %%
plot_value_distribution(df, "response")

# %%
df["end_time"] = pd.to_datetime(df["end_time"])
df["start_time"] = pd.to_datetime(df["start_time"])
df["duration"] = (df["end_time"] - df["start_time"]).dt.total_seconds()

# %%
df[["duration", "total_time"]].head()
# Out:
#     duration total_time
# 0  37.277277     0.2773
# 1  11.263929     0.2639
# 2  10.759058     0.7591
# 3  12.925786     0.9258
# 4  11.241722     0.2417

# %%
# plot the distribution of duration
df["duration"].plot(kind="hist", bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df[df["duration"] > 48]
# Out:
# Empty DataFrame
# Columns: [email_id, sender_email, recipient_email, subject, email_body, attachments, process_status, response, start_time, end_time, total_time, successful_requests, total_tokens, prompt_tokens, completion_tokens, total_cost, duration]
# Index: []

# %%
df["duration"].describe()
# Out:
# count    2000.000000
# mean       15.539130
# std         4.058765
# min         4.488136
# 25%        11.710267
# 50%        16.154809
# 75%        18.903692
# max        37.277277
# Name: duration, dtype: float64

# %%
plot_value_distribution(df, "successful_requests", top_n=30)

# %%
df["process_status"].value_counts()
# Out:
# process_status
# SUCCESS    1945
# ERROR        55
# Name: count, dtype: int64

# %%
success_rate = df["process_status"].value_counts()["SUCCESS"] / len(df)
success_rate
# Out:
# 0.9725

# %%
def total_power_in_watt(file_path):
    df = pd.read_csv(file_path)
    return df["CPU Package Power [W]"].mean() + df["GPU Power [W]"].mean()

# %%
power_idle = total_power_in_watt("results/power_idle.csv")
power_idle
# Out:
# 29.873

# %%
power_with_vision = total_power_in_watt(
    "results/llama3.2-vision_11b-qwen2.5_32b/power_with_vision.csv"
)
power_without_vision = total_power_in_watt(
    "results/llama3.2-vision_11b-qwen2.5_32b/power_without_vision.csv"
)
power_with_vision, power_without_vision
# Out:
# (329.757, 327.73380000000003)

# %%
mean_response_time = df["duration"].mean()
mean_response_time
# Out:
# 15.5391303695

# %%
average_energy_consumption = (
    (power_with_vision + power_without_vision) / 2 - power_idle
) * mean_response_time
average_energy_consumption
# Out:
# 4644.2171874453525

# %%
df.describe()
# Out:
#                           start_time                       end_time  \
# count                           2000                           2000
# mean   2025-01-19 16:37:49.302939648  2025-01-19 16:38:04.842070016
# min       2025-01-19 12:38:44.897633     2025-01-19 12:39:22.174910
# 25%    2025-01-19 14:27:22.921345024  2025-01-19 14:27:34.590950400
# 50%    2025-01-19 16:14:33.532849408  2025-01-19 16:14:50.019038976
# 75%    2025-01-19 18:49:53.654681856  2025-01-19 18:50:13.158118400
# max       2025-01-19 21:18:27.485899     2025-01-19 21:18:48.182059
# std                              NaN                            NaN
#
#           duration
# count  2000.000000
# mean     15.539130
# min       4.488136
# 25%      11.710267
# 50%      16.154809
# 75%      18.903692
# max      37.277277
# std       4.058765

# %%
row = df[df["process_status"] == "ERROR"].iloc[0]
row
# Out:
# email_id                                F2237157AD2542EB91ED5B4508C0B326
# sender_email                                     JerryHuerta@example.com
# recipient_email                             tanya.official.456@gmail.com
# subject                       Payment Confirmation for Invoice ID: 47535
# email_body             Hi Tanya ! Please find attached payment screen...
# attachments                                         transaction_126.jpeg
# process_status                                                     ERROR
# response               ERROR - The invoice amount does not match. Acc...
# start_time                                    2025-01-19 13:07:00.631371
# end_time                                      2025-01-19 13:07:09.543617
# total_time                                                        0.9122
# successful_requests                                                95507
# total_tokens                                                    38507238
# prompt_tokens                                                   31850057
# completion_tokens                                                6657181
# total_cost                                                           0.0
# duration                                                        8.912246
# Name: 125, dtype: object

# %%
full_logs[0]
# Out:
# {'name': 'input',
#  'type': 'HumanMessage',
#  'content': '\n                Help to reconcile invoices using the following email:\n\n                \n            Sender: RobinLevine@example.com\n            Subject: Payment Confirmation for Invoice ID: 43925\n            Body: Hi Tanya ! Please find attached payment screenshot for Invoice ID: 43925 , Regards Robin Levine\n            Attachment: transaction_1.jpeg\n            Time stamp: NOT_STARTED\n            \n                ',
#  'timestamp': '2025-01-19T21:18:27.485899',
#  'usage': {'input_tokens': 0,
#   'output_tokens': 0,
#   'total_tokens': 0,
#   'input_token_details': {'audio': 0, 'cache_read': 0},
#   'output_token_details': {'audio': 0, 'reasoning': 0}},
#  'model_name': '',
#  'additional_kwargs': {}}

# %%
for i, log in enumerate(full_logs):
    if row["attachments"] in log["content"]:
        print(i)
        break
# Out:
# 1125

# %%
full_logs[i : i + 5]
# Out:
# [{'name': 'input',
#   'type': 'HumanMessage',
#   'content': '\n                Help to reconcile invoices using the following email:\n\n                \n            Sender: JerryHuerta@example.com\n            Subject: Payment Confirmation for Invoice ID: 47535\n            Body: Hi Tanya ! Please find attached payment screenshot for Invoice ID: 47535 , Regards Jerry Huerta\n            Attachment: transaction_126.jpeg\n            Time stamp: NOT_STARTED\n            \n                ',
#   'timestamp': '2025-01-19T21:18:27.485899',
#   'usage': {'input_tokens': 0,
#    'output_tokens': 0,
#    'total_tokens': 0,
#    'input_token_details': {'audio': 0, 'cache_read': 0},
#    'output_token_details': {'audio': 0, 'reasoning': 0}},
#   'model_name': '',
#   'additional_kwargs': {}},
#  {'name': 'finance_clerk',
#   'type': 'AIMessage',
#   'content': 'Tool calls to ocr_tool',
#   'timestamp': '2025-01-19T13:07:01.652201',
#   'usage': {'input_tokens': 299,
#    'output_tokens': 26,
#    'total_tokens': 325,
#    'input_token_details': {},
#    'output_token_details': {}},
#   'model_name': 'qwen2.5:32b',
#   'additional_kwargs': {'tool_calls': [{'name': 'ocr_tool',
#      'args': {'image_path': 'transaction_126.jpeg'},
#      'id': 'call_rf707zse',
#      'type': 'tool_call'}]}},
#  {'name': 'ocr_tool',
#   'type': 'ToolMessage',
#   'content': '{"content": "Bank 906\\nSent by: Jerry Huerta\\nYou paid $186 to Tanya\\nTransaction Reference Number: B554FCC2CC674DC0\\nTransaction Date: 04/14/24\\nInvoice ID: 47535", "usage": {"successful_requests": 752, "total_tokens": 302171, "prompt_tokens": 250329, "completion_tokens": 51842, "total_cost": 0.0}}',
#   'timestamp': '2025-01-19T13:07:01.652201',
#   'usage': {'input_tokens': 0,
#    'output_tokens': 0,
#    'total_tokens': 0,
#    'input_token_details': {'audio': 0, 'cache_read': 0},
#    'output_token_details': {'audio': 0, 'reasoning': 0}},
#   'model_name': '',
#   'additional_kwargs': {}},
#  {'name': 'senior_reconciliation_agent',
#   'type': 'AIMessage',
#   'content': 'QUERY 47535\n\nTo verify if the invoice amount matches between the database and the email, please check for Invoice ID: 47535 with the following details:\n\n- Invoice ID: 47535\n- Amount: $186\n- Transaction Reference Number: B554FCC2CC674DC0\n- Sender: Jerry Huerta (JerryHuerta@example.com)\n\nPlease confirm if this amount matches the database record.',
#   'timestamp': '2025-01-19T13:07:06.616786',
#   'usage': {'input_tokens': 378,
#    'output_tokens': 101,
#    'total_tokens': 479,
#    'input_token_details': {},
#    'output_token_details': {}},
#   'model_name': 'qwen2.5:32b',
#   'additional_kwargs': {}},
#  {'name': 'invoice_data_engineer',
#   'type': 'AIMessage',
#   'content': 'Tool calls to invoice_db_query_tool',
#   'timestamp': '2025-01-19T13:07:07.601193',
#   'usage': {'input_tokens': 360,
#    'output_tokens': 27,
#    'total_tokens': 387,
#    'input_token_details': {},
#    'output_token_details': {}},
#   'model_name': 'qwen2.5:32b',
#   'additional_kwargs': {'tool_calls': [{'name': 'invoice_db_query_tool',
#      'args': {'invoice_id': '47535'},
#      'id': 'call_v36uaipq',
#      'type': 'tool_call'}]}}]
